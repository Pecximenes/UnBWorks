# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Bloco 1

# %% [markdown]
# ### Gráfico 1 -
# Contextualização dos significados dos empréstimos africanos encontrados no crioulo guineense

# %%
title1 = "Contextualização dos significados dos empréstimos africanos encontrados no crioulo guineense"
collumn_type1 = [
    "Ambiente religioso",
    "Ambiente familiar",
    "Tratamento social",
    "Acolhimento"
]
collumn_values1 = [3, 3, 5, 1]

# %%
# Create the line chart
plt.figure(figsize=(10, 6))
plt.pie(collumn_values1, labels=collumn_type1, autopct='%1.1f%%', colors=['purple', 'blue'])
plt.title(title1, fontsize=16)
plt.plot();

# %% [markdown]
# ### Gráfico 2 -
# Contexto do empréstimo africano no crioulo guineense: é ligado ao afeto ou desafeto?

# %%
# Data
labels2 = ['Afeto', 'Desafeto']
palavras2 = [9, 3]
expressoes2 = [3, 1]

# Create the plot with specified colors
plt.plot(labels2, palavras2, marker='o', linestyle='-', label='Palavras', color='blue')
plt.plot(labels2, expressoes2, marker='o', linestyle='-', label='Expressões', color='purple')

# Add titles and labels
plt.title('Contexto do empréstimo africano no crioulo guineense: é ligado ao afeto ou desafeto?')
plt.xlabel('Sentimento')
plt.ylabel('Contagem')
plt.legend()
plt.grid(True)

# %% [markdown]
# # Bloco 2

# %% [markdown]
# ### Gráfico 3 –
# Contextualização dos significados dos empréstimos africanos encontrados no crioulo cabo-verdiano

# %%
title3 = "Contextualização dos significados dos empréstimos africanos encontrados no crioulo cabo-verdiano"
collumn_type3 = [
    "Ambiente familiar",
    "Tratamento social"
]
collumn_values3 = [1, 3]

# %%
# Create the line chart
plt.figure(figsize=(10, 6))
plt.pie(collumn_values3, labels=collumn_type3, autopct='%1.1f%%', colors=['purple', 'blue'])
plt.title(title3, fontsize=16)
plt.plot();

# %% [markdown]
# ### Gráfico 4 –
# Contexto do empréstimo africano no crioulo cabo-verdiano:
# é ligado ao afeto ou desafeto?

# %%
# Data
labels4 = ['Afeto', 'Desafeto']
palavras4 = [2, 2]
expressoes4 = [2, 0]

# Create the plot with specified colors
plt.plot(labels4, palavras4, marker='o', linestyle='-', label='Palavras', color='blue')
plt.plot(labels4, expressoes4, marker='o', linestyle='-', label='Expressões', color='purple')

# Add titles and labels
plt.title('Contexto do empréstimo africano no crioulo cabo-verdiano: é ligado ao afeto ou desafeto?')
plt.xlabel('Sentimento')
plt.ylabel('Contagem')
plt.legend()
plt.grid(True)

# %% [markdown]
# # Bloco 3

# %% [markdown]
# ## Gráfico 5 –
# Contextualização dos significados dos empréstimos africanos encontrados no português brasileiro

# %%
title5 = "Contextualização dos significados dos empréstimos africanos encontrados no crioulo guineense"
collumn_type5 = [
    "Ambiente religioso",
    "Ambiente familiar",
    "Tratamento social",
    "Acolhimento"
]
collumn_values5 = [5, 9, 8, 3]

# %%
# Create the line chart
plt.figure(figsize=(10, 6))
plt.pie(collumn_values5, labels=collumn_type5, autopct='%1.1f%%', colors=['purple', 'blue'])
plt.title(title5, fontsize=16)
plt.plot();

# %% [markdown]
# ### Gráfico 6 –
# Contexto do empréstimo africano no português brasileiro: é ligado ao afeto ou desafeto?

# %%
# Data
labels6 = ['Afeto', 'Desafeto']
palavras6 = [22, 3]
expressoes6 = [1, 1]

# Create the plot with specified colors
plt.plot(labels6, palavras6, marker='o', linestyle='-', label='Palavras', color='blue')
plt.plot(labels6, expressoes6, marker='o', linestyle='-', label='Expressões', color='purple')

# Add titles and labels
plt.title('Contexto do empréstimo africano no português brasileiro: é ligado ao afeto ou desafeto?')
plt.xlabel('Sentimento')
plt.ylabel('Contagem')
plt.legend()
plt.grid(True)
